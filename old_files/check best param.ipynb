# %%
import pandas as pd

# %%
df = pd.read_csv(
    "подбор_комбинаций.csv",
    sep=",",        # разделитель
    encoding="utf-8",
    decimal=".",    # если числа с точкой
)

# %%
df.head()      # первые строки
df.info()      # типы данных
df.describe()  # статистика
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30184 entries, 0 to 30183
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rank             30184 non-null  int64
#  1   total_error_pct  30184 non-null  float64
#  2   d1_отн           30184 non-null  float64
#  3   c_а1_отн         30184 non-null  float64
#  4   с_а_отн          30184 non-null  float64
#  5   Hт_ср_отн        30184 non-null  float64
#  6   H_т1             30184 non-null  float64
#  7   π_к_полн         30184 non-null  float64
#  8   η_к_полн         30184 non-null  float64
#  9   err_π_к_pct      30184 non-null  float64
#  10  err_η_к_pct      30184 non-null  float64
# dtypes: float64(10), int64(1)
# memory usage: 2.5 MB
#                rank  total_error_pct        d1_отн      c_а1_отн  \
# count  30184.000000     30184.000000  30184.000000  30184.000000
# mean   15092.500000       167.270875      0.450000      0.550000
# ...

# %%
df_sorted = df.sort_values("err_η_к_pct", ascending=True)

# %%
filtered_sorted = df[
    (df["c_а1_отн"] > df["с_а_отн"])
    ].sort_values("err_η_к_pct", ascending=True)

# %%
filtered_sorted
# Out:
#         rank  total_error_pct  d1_отн  c_а1_отн  с_а_отн  Hт_ср_отн  H_т1  \
# 13781  13782        56.907990    0.30       0.5     0.45        0.4  0.25
# 13757  13758        56.844313    0.30       0.5     0.45        0.4  0.24
# 13734  13735        56.778223    0.30       0.5     0.45        0.4  0.23
# 13707  13708        56.709689    0.30       0.5     0.45        0.4  0.22
# 13682  13683        56.638678    0.30       0.5     0.45        0.4  0.21
# ...      ...              ...     ...       ...      ...        ...   ...
# 29025  29026       929.340370    0.30       0.4     0.25        0.1  0.21
# 29081  29082       938.748525    0.35       0.4     0.25        0.1  0.19
# 29041  29042       932.208739    0.30       0.4     0.25        0.1  0.20
# 29060  29061       935.179795    0.30       0.4     0.25        0.1  0.19
# 29079  29080       938.255317    0.30       0.4     0.25        0.1  0.18
#
#          π_к_полн  η_к_полн  err_π_к_pct  err_η_к_pct
# ...
